# %% [markdown]
# <a href="https://colab.research.google.com/github/Mokshitha1607/insurance-claim-fraud-detection/blob/main/Insurance_Claim_Fraud_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Insurance Claim Fraud Detection System

## Objective
Build a machine learning system to identify potentially fraudulent insurance claims.

## Technologies
- Python
- Pandas
- NumPy
- Matplotlib
- Seaborn
- Scikit-learn
- Imbalanced-learn (SMOTE)
